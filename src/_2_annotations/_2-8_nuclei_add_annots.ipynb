# %% [markdown]
# # Add annotations and final annots into sdata / Using nuclei

# %%
import scanpy as sc
import anndata as ad
import spatialdata as sd
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib.colors import to_rgba
from functools import partial
from matplotlib import colors

# %% [markdown]
# ## 1. Get final labels

# %% [markdown]
# ### 1.1. Get initial labels

# %%
def build_labels_table(adata_files, csv):
    
    combination_data = []
    
    if os.path.exists(csv):
        df_labels = pd.read_csv(csv)
    else:
        df_labels = pd.DataFrame(columns=['sample_id', 'tissue', 'label1', 'label2', 'label3', 'cell_count'])

    for file in adata_files:

        adata = ad.read_h5ad(file)
        file_name = os.path.basename(file)
        sample_id = file_name.replace('adata_refine_tangram_', '').replace('.h5ad', '')
        tissue = sample_id.rsplit('_', 1)[0]
        print("Reading file: ", file_name)

        combination_counts = adata.obs.groupby(['label1', 'label2', 'label3'], observed=True).size().reset_index(name='cell_count')
        
        combination_counts['sample_id'] = sample_id
        combination_counts['tissue'] = tissue
        
        combination_counts = combination_counts[['sample_id', 'tissue', 'label1', 'label2', 'label3', 'cell_count']]
        combination_data.append(combination_counts)

    new_combination_df = pd.concat(combination_data, ignore_index=True)

    df_labels = pd.concat([df_labels, new_combination_df], ignore_index=True).drop_duplicates()
    df_labels.to_csv(csv, index=False)
    
    return df_labels

# %%
adata_dir = "/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram"
adata_files = [os.path.join(adata_dir, f) for f in os.listdir(adata_dir) if f.endswith('.h5ad')]
print(f"Number of adata files: {len(adata_files)}")
print(adata_files)
# Out:
# Number of adata files: 31
# ['/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_breast_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_breast_s1.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_breast_s3.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_skin_s1.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_skin_s2.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_skin_s3.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_heart_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_tonsil_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_tonsil_s1.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_liver_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_liver_s1.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_pancreatic_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_colon_s1.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_kidney_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_kidney_s1.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_lung_s1.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_skin_s4.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_pancreatic_s1.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_pancreatic_s2.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_colon_s2.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_bone_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_bone_marrow_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_bone_marrow_s1.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_brain_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_ovary_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_prostate_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_ovary_s1.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_lymph_node_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_cervix_s0.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_lung_s3.h5ad', '/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_breast_s6.h5ad']

# %%
df_labels = build_labels_table(adata_files, '/Users/felicie-giraud-sauveur/Documents/HE2CellType/code/CT_DS/data/annots/labels_table_nuclei.csv')
# Out:
# Reading file:  adata_refine_tangram_breast_s0.h5ad
# Reading file:  adata_refine_tangram_breast_s1.h5ad
# Reading file:  adata_refine_tangram_breast_s3.h5ad
# Reading file:  adata_refine_tangram_skin_s1.h5ad
# Reading file:  adata_refine_tangram_skin_s2.h5ad
# Reading file:  adata_refine_tangram_skin_s3.h5ad
# Reading file:  adata_refine_tangram_heart_s0.h5ad
# Reading file:  adata_refine_tangram_tonsil_s0.h5ad
# Reading file:  adata_refine_tangram_tonsil_s1.h5ad
# Reading file:  adata_refine_tangram_liver_s0.h5ad
# Reading file:  adata_refine_tangram_liver_s1.h5ad
# Reading file:  adata_refine_tangram_pancreatic_s0.h5ad
# Reading file:  adata_refine_tangram_colon_s1.h5ad
# Reading file:  adata_refine_tangram_kidney_s0.h5ad
# Reading file:  adata_refine_tangram_kidney_s1.h5ad
# Reading file:  adata_refine_tangram_lung_s1.h5ad
# Reading file:  adata_refine_tangram_skin_s4.h5ad
# Reading file:  adata_refine_tangram_pancreatic_s1.h5ad
# Reading file:  adata_refine_tangram_pancreatic_s2.h5ad
# Reading file:  adata_refine_tangram_colon_s2.h5ad
# Reading file:  adata_refine_tangram_bone_s0.h5ad
# Reading file:  adata_refine_tangram_bone_marrow_s0.h5ad
# Reading file:  adata_refine_tangram_bone_marrow_s1.h5ad
# Reading file:  adata_refine_tangram_brain_s0.h5ad
# Reading file:  adata_refine_tangram_ovary_s0.h5ad
# Reading file:  adata_refine_tangram_prostate_s0.h5ad
# Reading file:  adata_refine_tangram_ovary_s1.h5ad
# Reading file:  adata_refine_tangram_lymph_node_s0.h5ad
# Reading file:  adata_refine_tangram_cervix_s0.h5ad
# Reading file:  adata_refine_tangram_lung_s3.h5ad
# Reading file:  adata_refine_tangram_breast_s6.h5ad

# %% [markdown]
# ### 1.2. Transform into final labels

# %%
df_labels = pd.read_csv('/Users/felicie-giraud-sauveur/Documents/HE2CellType/code/CT_DS/data/annots/labels_table_nuclei.csv')

# %%
df_labels
# Out:
#      sample_id  tissue                  label1  \
# 0    breast_s0  breast               Adipocyte
# 1    breast_s0  breast                       B
# 2    breast_s0  breast             Endothelial
# 3    breast_s0  breast              Epithelial
# 4    breast_s0  breast              Epithelial
# ..         ...     ...                     ...
# 302  breast_s6  breast                    Mast
# 303  breast_s6  breast  Monocyte/Macrophage/DC
# 304  breast_s6  breast                  Plasma
# 305  breast_s6  breast                       T
# 306  breast_s6  breast                 Unknown
#
#                                   label2       label3  cell_count
# 0                              Adipocyte  normal_cell         737
# 1                                      B  normal_cell       17676
# 2                            Endothelial  normal_cell       19598
# 3         Mammary_basal_and_luminal_cell  cancer_cell       57672
# 4    Mammary_basal_cell_(=myoepithelial)  cancer_cell       21811
# ..                                   ...          ...         ...
# 302                                 Mast  normal_cell        4591
# 303               Monocyte/Macrophage/DC  normal_cell       32580
# 304                               Plasma  normal_cell       12485
# 305                                    T  normal_cell       96860
# 306                              Unknown  normal_cell      124946
#
# [307 rows x 6 columns]

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=df_labels, 
             x='label1', 
             hue='label3', 
             weights='cell_count',  # Use the cell count for actual counts
             multiple='stack', 
             shrink=0.8, 
             palette='Set2')

plt.yscale('log')
plt.xlabel('Label1', fontsize=14)
plt.ylabel('Cell Count', fontsize=14)
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
group_labels = {

    # T/NK
    "T" : "T_NK",
    "T/NK" : "T_NK",
    "NK" : "T_NK",
    
    # B
    "B" : "B_Plasma",
    "B_blast" : "B_Plasma",
    "Proliferating_B_T" : "B_Plasma",
    "Plasma" : "B_Plasma",
    "B_progenitor" : "B_Plasma",
    
    # Monocyte/Macrophage/DC
    "Monocyte/Macrophage" : "Myeloid",
    "Monocyte/Macrophage/DC" : "Myeloid",
    "Macrophage" : "Myeloid",
    "DC" : "Myeloid",
    "Macrophage/DC" : "Myeloid",
    "Neutrophil" : "Myeloid",
    "Monocyte/Neutrophil" : "Myeloid",
    "Mast" : "Myeloid",
    "Myeloid" : "Myeloid",
    "Myeloid/Neutrophil" : "Myeloid",
    "pDC" : "Myeloid",  # not exactly true but convenient for now

    # Fibroblast/Myofibroblast
    "Fibroblast" : "Fibroblast_Myofibroblast",
    "Fibroblast/Myofibroblast" : "Fibroblast_Myofibroblast",
    "Mesenchymal_stromal_cell" : "Fibroblast_Myofibroblast",
    "Myofibroblast" : "Fibroblast_Myofibroblast",

    # Blood_vessel
    "Perivascular" : "Blood_vessel",
    "Smooth_muscle" : "Blood_vessel",
    "Pericyte" : "Blood_vessel",
    "Myofibroblast/Pericyte" : "Blood_vessel",
    "Endothelial" : "Blood_vessel",
    "Blood_vessel" : "Blood_vessel",
    
    # Epithelial
    "Epithelial" : "Epithelial",
    "Keratinocyte" : "Epithelial",

    # Melanocyte
    "Melanocyte" : "Melanocyte",
    "Melanoma" : "Melanocyte",

    # Stem_like
    "Cancer_cell_with_stem_like_properties" : "Stem_like",
    "Proliferating_leukemic_blast" : "Stem_like",
    "Proliferating_blast" : "Stem_like",
    "Cancer_stem_like_cells" : "Stem_like",
    "Stem_like_cell" : "Stem_like",

    # Glioblastoma
    "Glioblastoma_tumor_cell_astrocyte_derived" : "Glioblastoma",

    # Specialized
    "Erythroid_cell" : "Specialized",
    "Osteoclast" : "Specialized",
    "Osteoblast" : "Specialized",
    "Cardiomyocyte" : "Specialized",
    "Adipocyte" : "Specialized",
    "Endocrine" : "Specialized",
    "Valvular_interstitial_cell" : "Specialized",

    # Unknown
    "Unknown" : "Unknown",
    "ToRemove" : "Unknown",
    "Osteoblast/Unknown" : "Unknown",
    "Osteoblast/Unknown/Myeloid" : "Unknown",
}

# %%
df_labels['final_label'] = df_labels['label1'].map(group_labels)

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=df_labels,
             x='final_label', 
             hue='label3', 
             weights='cell_count',  # Use the cell count for actual counts
             multiple='stack', 
             shrink=0.8, 
             palette='Set2')

plt.yscale('log')
plt.xlabel('final_label', fontsize=14)
plt.ylabel('Cell Count', fontsize=14)
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
# df_labels['final_label'] = df_labels.apply(
#     lambda row: f"{row['final_label']}_cancer" if row['label3'] == 'cancer_cell' else row['final_label'],
#     axis=1
# )

# %%
# plt.figure(figsize=(12, 8))

# sns.histplot(data=df_labels,
#              x='final_label', 
#              hue='label3', 
#              weights='cell_count',  # Use the cell count for actual counts
#              multiple='stack', 
#              shrink=0.8, 
#              palette='Set2')

# plt.xlabel('final_label', fontsize=14)
# plt.ylabel('Cell Count', fontsize=14)
# plt.xticks(rotation=45, ha='right')

# plt.tight_layout()
# plt.show()

# %%
df_labels['final_label'].unique()
# Out:
# array(['Specialized', 'B_Plasma', 'Blood_vessel', 'Epithelial',
#        'Fibroblast_Myofibroblast', 'Myeloid', 'T_NK', 'Melanocyte',
#        'Unknown', 'Stem_like', 'Glioblastoma'], dtype=object)

# %%
df_labels["final_label"].value_counts()
# Out:
# final_label
# Myeloid                     63
# Epithelial                  56
# Blood_vessel                47
# T_NK                        39
# B_Plasma                    36
# Fibroblast_Myofibroblast    34
# Unknown                     10
# Specialized                  9
# Melanocyte                   7
# Stem_like                    5
# Glioblastoma                 1
# Name: count, dtype: int64

# %%
# dict_final = {
    
#     'T_NK' : 'T_NK',
#     'B' : 'B', 
#     'Plasma' : 'Plasma', 
#     'Myeloid' : 'Myeloid',
#     'pDC' : 'pDC',

#     'Fibroblast_Myofibroblast' : 'Fibroblast_Myofibroblast',
#     'Blood_vessel' : 'Blood_vessel', 
#     'Epithelial' : 'Epithelial',

#     'Epithelial_cancer' : 'Epithelial_cancer',
#     'Melanocyte_cancer' : 'Melanoma_cancer',
#     'B_cancer' : 'B_cancer', 
#     'Stem_like_cancer' : 'Stem_like_cancer', 
#     'Glioblastoma_cancer' : 'Glioblastoma_cancer',
        
#     'Specialized' : 'Specialized', 
#     'Melanocyte' : 'Specialized', 
                
#     'Unknown' : 'Unknown', 
# }

# %%
# df_labels['final_label'] = df_labels['final_label'].map(dict_final)

# %%
plt.figure(figsize=(7, 5))

sns.histplot(data=df_labels,
             x='final_label', 
             hue='label3', 
             weights='cell_count',  # Use the cell count for actual counts
             multiple='stack', 
             shrink=0.8, 
             palette='Set2')

plt.yscale('log')
plt.xlabel('final_label', fontsize=14)
plt.ylabel('Cell Count', fontsize=14)
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
len(df_labels['final_label'].unique())
# Out:
# 11

# %%
df_labels["final_label"].unique()
# Out:
# array(['Specialized', 'B_Plasma', 'Blood_vessel', 'Epithelial',
#        'Fibroblast_Myofibroblast', 'Myeloid', 'T_NK', 'Melanocyte',
#        'Unknown', 'Stem_like', 'Glioblastoma'], dtype=object)

# %%
# dict to put final label in each anndata

df_labels['combined_labels'] = df_labels[['label1', 'label2', 'label3']].astype(str).agg('_'.join, axis=1)
label_dict = df_labels.set_index('combined_labels')['final_label'].to_dict()
label_dict_unique = {k: v for k, v in label_dict.items()}
label_dict_unique
# Out:
# {'Adipocyte_Adipocyte_normal_cell': 'Specialized',
#  'B_B_normal_cell': 'B_Plasma',
#  'Endothelial_Endothelial_normal_cell': 'Blood_vessel',
#  'Epithelial_Mammary_basal_and_luminal_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Mammary_basal_cell_(=myoepithelial)_cancer_cell': 'Epithelial',
#  'Epithelial_Mammary_luminal_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Proliferating_mammary_luminal_epithelial_cell_cancer_cell': 'Epithelial',
#  'Fibroblast_CAF_normal_cell': 'Fibroblast_Myofibroblast',
#  'Mast_Mast_normal_cell': 'Myeloid',
#  'Monocyte/Macrophage_Monocyte/Macrophage_normal_cell': 'Myeloid',
#  'Perivascular_Smooth_muscle_cell_and_pericyte_normal_cell': 'Blood_vessel',
#  'T_T_normal_cell': 'T_NK',
#  'Epithelial_Mammary_basal_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Basal_keatinocyte_normal_cell': 'Epithelial',
#  'Epithelial_Keratinocyte_normal_cell': 'Epithelial',
#  'Epithelial_Proliferating_basal_keratinocyte_normal_cell': 'Epithelial',
#  'Fibroblast_Fibroblast_normal_cell': 'Fibroblast_Myofibroblast',
#  'Macrophage/DC_Macrophage/DC_normal_cell': 'Myeloid',
#  'Melanocyte_Melanocyte_normal_cell': 'Melanocyte',
#  'Smooth_muscle_Smooth_muscle_normal_cell': 'Blood_vessel',
#  'DC_DC_normal_cell': 'Myeloid',
#  'Melanocyte_High_proliferating_melanocyte_cancer_cell': 'Melanocyte',
#  'Melanocyte_Melanocyte_cancer_cell': 'Melanocyte',
#  'Monocyte/Macrophage/DC_Monocyte/Macrophage/DC_normal_cell': 'Myeloid',
#  'T_Treg_normal_cell': 'T_NK',
#  'T/NK_T/NK_normal_cell': 'T_NK',
#  'Cardiomyocyte_Cardiomyocyte_normal_cell': 'Specialized',
#  'Perivascular_Smooth_muscle_normal_cell': 'Blood_vessel',
#  'Perivascular_Smooth_muscle_and_pericyte_normal_cell': 'Blood_vessel',
#  'ToRemove_ToRemove_normal_cell': 'Unknown',
#  'Valvular_interstitial_cell_Valvular_interstitial_cell_normal_cell': 'Specialized',
#  'B_Proliferating_B_normal_cell': 'B_Plasma',
#  'DC_Follicular_DC_normal_cell': 'Myeloid',
#  'Epithelial_Epithelial_normal_cell': 'Epithelial',
#  'Plasma_Plasma_normal_cell': 'B_Plasma',
#  'T_Proliferating_Treg_normal_cell': 'T_NK',
#  'T_T_CD8_normal_cell': 'T_NK',
#  'pDC_pDC_normal_cell': 'Myeloid',
#  'Epithelial_Cholangiocytes_normal_cell': 'Epithelial',
#  'Epithelial_Hepatocyte_normal_cell': 'Epithelial',
#  'Epithelial_Cholangiocyte_normal_cell': 'Epithelial',
#  'Epithelial_Hepatocyte_cancer_cell': 'Epithelial',
#  'Epithelial_High_proliferating_hepatocyte_cancer_cell': 'Epithelial',
#  'Myofibroblast_Myofibroblast_normal_cell': 'Fibroblast_Myofibroblast',
#  'Endocrine_Pancreatic_islet_cell_normal_cell': 'Specialized',
#  'Epithelial_High_proliferating_pancreatic_acinar_cell_normal_cell': 'Epithelial',
#  'Epithelial_Pancreatic_ductal_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Pancreatic_ductal_cell_normal_cell': 'Epithelial',
#  'Epithelial_Pancreatic_epithelial_cell_normal_cell': 'Epithelial',
#  'Macrophage_Macrophage_normal_cell': 'Myeloid',
#  'Epithelial_Colorectal_epithelial_cell_normal_cell': 'Epithelial',
#  'Epithelial_High_proliferative_epithelial_cell_cancer_cell': 'Epithelial',
#  'Pericyte_Pericyte_normal_cell': 'Blood_vessel',
#  'Epithelial_Collecting_duct_epithelial_cell_normal_cell': 'Epithelial',
#  'Epithelial_Epithelial_intercalated_cells_of_the_collecting_duct_normal_cell': 'Epithelial',
#  'Epithelial_Podocyte_and_other_renal_epithelial_cells_normal_cell': 'Epithelial',
#  'Epithelial_Renal_Loop_of_Henle_or_distal_tubules_epithelial_cell_normal_cell': 'Epithelial',
#  'Epithelial_Renal_proximal_tubule_epithelial_cell_normal_cell': 'Epithelial',
#  'Fibroblast/Myofibroblast_Fibroblast/Myofibroblast_normal_cell': 'Fibroblast_Myofibroblast',
#  'Myofibroblast/Pericyte_Myofibroblast/Pericyte_normal_cell': 'Blood_vessel',
#  'Epithelial_Renal_epithelial_cell_cancer_cell': 'Epithelial',
#  'NK_NK_normal_cell': 'T_NK',
#  'Unknown_Unknown_normal_cell': 'Unknown',
#  'Endothelial_Angiogenesis_endothelial_cell_normal_cell': 'Blood_vessel',
#  'Epithelial_Cancerous_lung_epithelial_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Lung_epithelial_cell_normal_cell': 'Epithelial',
#  'Cancer_stem_like_cells_Cancer_stem_like_cells_cancer_cell': 'Stem_like',
#  'Keratinocyte_Keratinocyte_normal_cell': 'Epithelial',
#  'Melanoma_High_proliferating_melanoma_cancer_cell': 'Melanocyte',
#  'Melanoma_Melanoma_cancer_cell': 'Melanocyte',
#  'T/NK_Proliferating_T_NK_normal_cell': 'T_NK',
#  'Epithelial_Pancreatic_ductal_epithelial_cell_cancer_cell': 'Epithelial',
#  'Endocrine_Beta_Alpha_Delta _cells_of_pancreatic_islets_normal_cell': 'Specialized',
#  'Epithelial_Cancerous_pancreatic_ductal_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Pancreatic_acinar_cell_normal_cell': 'Epithelial',
#  'Epithelial_Pancreatic_acinar_ductal_cell_normal_cell': 'Epithelial',
#  'Endothelial_Angiogenesis_endothelial_cells_normal_cell': 'Blood_vessel',
#  'Epithelial_Cancerous_intestinal_epithelial_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Cancerous_intestinal_epithelial_cells_with_stem_like_properties_cancer_cell': 'Epithelial',
#  'Osteoblast_Osteoblast_normal_cell': 'Specialized',
#  'Osteoclast_Osteoclast_normal_cell': 'Specialized',
#  'B_Leukemic_B_cell_cancer_cell': 'B_Plasma',
#  'B_blast_Leukemic_B_cell_blast_cancer_cell': 'B_Plasma',
#  'Mesenchymal_stromal_cell_MSC_normal_cell': 'Fibroblast_Myofibroblast',
#  'Monocyte/Neutrophil_Monocyte/Neutrophil_normal_cell': 'Myeloid',
#  'Proliferating_blast_Proliferating_blast_cancer_cell': 'Stem_like',
#  'Proliferating_leukemic_blast_Proliferating_leukemic_blast_cancer_cell': 'Stem_like',
#  'Erythroid_cell_Erythroid_cell_normal_cell': 'Specialized',
#  'Neutrophil_Neutrophil_normal_cell': 'Myeloid',
#  'Glioblastoma_tumor_cell_astrocyte_derived_Glioblastoma_tumor_cell_astrocyte_derived_cancer_cell': 'Glioblastoma',
#  'Epithelial_Ovarian_epithelial_cancer_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Proliferating_ovarian_epithelial_cancer_cell_cancer_cell': 'Epithelial',
#  'Cancer_cell_with_stem_like_properties_Prostate_cancer_cell_with_stem_like_properties_cancer_cell': 'Stem_like',
#  'Epithelial_Prostate_epithelial_cancer_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Cancerous_ovarian_epithelial_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Proliferating_cancerous_ovarian_epithelial_cell_cancer_cell': 'Epithelial',
#  'Stem_like_cell_Cancer_stem_like_cell_cancer_cell': 'Stem_like',
#  'Proliferating_B_T_Proliferating_B_T_normal_cell': 'B_Plasma',
#  'Epithelial_Cancerous_cervical_epithelial_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Lung_alveolar_typeII_epithelial_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Lung_alveolar_typeI_epithelial_cell_normal_cell': 'Epithelial',
#  'Epithelial_Lung_ciliated_epithelial_cell_normal_cell': 'Epithelial',
#  'Epithelial_Lung_epithelial_cell_cancer_cell': 'Epithelial',
#  'Epithelial_Lung_proliferating_epithelial_cell_cancer_cell': 'Epithelial',
#  'Perivascular_Pericyte/Smooth_muscle_normal_cell': 'Blood_vessel',
#  'Endothelial_Angiogenesis_endothelial_normal_cell': 'Blood_vessel',
#  'Epithelial_Breast_epithelial_cell_cancer_cell': 'Epithelial'}

# %%
label_dict_unique["less10_less10_less10"] = "Less10"

# %%
# Save dict label_dict_unique in json file
with open("/Users/felicie-giraud-sauveur/Documents/HE2CellType/code/CT_DS/data/annots/label_dict_unique_nuclei.json", "w") as f:
    json.dump(label_dict_unique, f)

# %%
# Save df_labels in csv file
df_labels.to_csv('/Users/felicie-giraud-sauveur/Documents/HE2CellType/code/CT_DS/data/annots/labels_table_nuclei.csv', index=False)

# %% [markdown]
# ## 2. Analyze final dataset

# %%
# Cell count per tissue, stacked by cell type

df_tissue_stacked = df_labels.pivot_table(index='tissue', columns='final_label', values='cell_count', aggfunc='sum', fill_value=0)
df_tissue_percentage = df_tissue_stacked.div(df_tissue_stacked.sum(axis=1), axis=0) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: Stacked bar plot with percentages and log scale
df_tissue_percentage.plot(kind='bar', stacked=True, colormap='tab20', ax=ax1, legend=False)

ax1.set_title('Cell Percentage per Tissue (Stacked by Cell Type)')
ax1.set_xlabel('Tissue')
ax1.set_ylabel('Percentage')
ax1.set_xticklabels(df_tissue_percentage.index, rotation=85)

# Plot 2: Stacked bar plot with count
df_tissue_stacked.plot(kind='bar', stacked=True, colormap='tab20', ax=ax2, legend=False)

ax2.set_title('Cell Count per Tissue (Stacked by Cell Type)')
ax2.set_xlabel('Tissue')
ax2.set_ylabel('Count')
ax2.set_xticklabels(df_tissue_stacked.index, rotation=85)

# Create a single legend and place it outside the plot
handles, labels = ax1.get_legend_handles_labels()  # Get the legend info from one of the plots
fig.legend(handles, labels, title='Cell Type', bbox_to_anchor=(1.05, 0.5), loc='center left')

# Adjust layout for clarity
plt.tight_layout()  # Leave space on the right for the legend
plt.show()

# %%
# Cell count per sample_id, stacked by cell type

df_sample_stacked = df_labels.pivot_table(index='sample_id', columns='final_label', values='cell_count', aggfunc='sum', fill_value=0)
df_sample_percentage = df_sample_stacked.div(df_sample_stacked.sum(axis=1), axis=0) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: Stacked bar plot with percentages and log scale
df_sample_percentage.plot(kind='bar', stacked=True, colormap='tab20', ax=ax1, legend=False)

ax1.set_title('Cell Percentage per Sample ID (Stacked by Cell Type)')
ax1.set_xlabel('Sample ID')
ax1.set_ylabel('Percentage')
ax1.set_xticklabels(df_sample_percentage.index, rotation=85)

# Plot 2: Stacked bar plot with count
df_sample_stacked.plot(kind='bar', stacked=True, colormap='tab20', ax=ax2, legend=False)

ax2.set_title('Cell Count per Sample ID (Stacked by Cell Type)')
ax2.set_xlabel('Sample ID')
ax2.set_ylabel('Count')
ax2.set_xticklabels(df_sample_stacked.index, rotation=85)

# Create a single legend and place it outside the plot
handles, labels = ax1.get_legend_handles_labels()  # Get the legend info from one of the plots
fig.legend(handles, labels, title='Cell Type', bbox_to_anchor=(1.05, 0.5), loc='center left')

# Adjust layout for clarity
plt.tight_layout()  # Leave space on the right for the legend
plt.show()

# %%
# Cell count per cell type, stacked by tissue

df_cell_type_stacked = df_labels.pivot_table(index='final_label', columns='tissue', values='cell_count', aggfunc='sum', fill_value=0)
df_cell_type_percentage = df_cell_type_stacked.div(df_cell_type_stacked.sum(axis=1), axis=0) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: Stacked bar plot with percentages and log scale
df_cell_type_percentage.plot(kind='bar', stacked=True, colormap='tab20', ax=ax1, legend=False)

ax1.set_title('Cell Percentage per Cell Type (Stacked by Cell Type)')
ax1.set_xlabel('Cell Type')
ax1.set_ylabel('Percentage')
ax1.set_xticklabels(df_cell_type_percentage.index, rotation=85)

# Plot 2: Stacked bar plot with count
df_cell_type_stacked.plot(kind='bar', stacked=True, colormap='tab20', ax=ax2, legend=False)

ax2.set_title('Cell Count per Cell Type (Stacked by Tissue)')
ax2.set_xlabel('Tissue Type')
ax2.set_ylabel('Count')
ax2.set_xticklabels(df_cell_type_stacked.index, rotation=85)

# Create a single legend and place it outside the plot
handles, labels = ax1.get_legend_handles_labels()  # Get the legend info from one of the plots
fig.legend(handles, labels, title='Cell Type', bbox_to_anchor=(1.05, 0.65), loc='center left')

# Adjust layout for clarity
plt.tight_layout()  # Leave space on the right for the legend
plt.show()

# %%
# Pie charts for tissue distribution in each cell type

df_grouped = df_labels.groupby(['final_label', 'tissue'])['cell_count'].sum().unstack(fill_value=0)

n_cell_types = len(df_grouped)
n_cols = 3 
n_rows = (n_cell_types // n_cols) + (n_cell_types % n_cols > 0)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 5))
axes = axes.flatten()

for i, (cell_type, row) in enumerate(df_grouped.iterrows()):
    ax = axes[i]
    ax.pie(row, labels=row.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
    ax.set_title(f'{cell_type}')
    ax.axis('equal')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Apply final labels to each slide

# %%
# Load the label_dict_unique from the JSON file
with open('/Users/felicie-giraud-sauveur/Documents/HE2CellType/code/CT_DS/data/annots/label_dict_unique_nuclei.json', 'r') as f:
    label_dict_unique = json.load(f)

# %%
# print unique values in label_dict_unique
print(set(label_dict_unique.values()))
# Out:
# {'Melanocyte', 'T_NK', 'Glioblastoma', 'Fibroblast_Myofibroblast', 'Stem_like', 'Blood_vessel', 'Less10', 'B_Plasma', 'Unknown', 'Specialized', 'Myeloid', 'Epithelial'}

# %%
# Color for final label in Napari

to_hex = partial(colors.to_hex, keep_alpha=True)

# Normalize the RGB values to the range [0, 1] by dividing by 255
napari_color = {
                "T_NK": to_hex(to_rgba([255/255, 15/255, 15/255])[:3]),                      # Red
                "B_Plasma": to_hex(to_rgba([255/255, 143/255, 15/255])[:3]),                 # Orange
                "Myeloid": to_hex(to_rgba([255/255, 211/255, 15/255])[:3]),                  # Yellow
                "Blood_vessel": to_hex(to_rgba([70/255, 128/255, 0/255])[:3]),               # Dark Green
                "Fibroblast_Myofibroblast": to_hex(to_rgba([156/255, 255/255, 36/255])[:3]), # Light Green
                "Epithelial": to_hex(to_rgba([57/255, 208/255, 133/255])[:3]),               # Blue Green
                "Specialized": to_hex(to_rgba([69/255, 237/255, 255/255])[:3]),              # Turquoise
                "Melanocyte": to_hex(to_rgba([22/255, 169/255, 223/255])[:3]),               # Blue
                "Stem_like": to_hex(to_rgba([22/255, 69/255, 223/255])[:3]),                 # Dark Blue
                "Glioblastoma": to_hex(to_rgba([130/255, 55/255, 235/255])[:3]),             # Purple
                "Unknown": to_hex(to_rgba([0/255, 0/255, 0/255])[:3]),                       # Black
                "Less10": to_hex(to_rgba([143/255, 143/255, 143/255])[:3])                   # Grey
                }

# %%
def apply_final_labels(slide_id):

    print(f"\n===== Processing slide {slide_id} =====")

    print("* Reading adata_annot...")
    adata_annot = sc.read_h5ad(f"/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/adata_refine_tangram/adata_refine_tangram_{slide_id}.h5ad")
    print("* Reading sdata_final...")
    sdata_final = sd.read_zarr(f"/Volumes/SAUV_FGS/MICS/data_HE2CellType/CT_DS/sdata_final/sdata_{slide_id}.zarr", selection=('tables',))

    print("* Applying final labels...")
    adata_annot.obs['combined_labels'] = adata_annot.obs[['label1', 'label2', 'label3']].astype(str).agg('_'.join, axis=1)
    adata_annot.obs['final_label'] = adata_annot.obs['combined_labels'].map(label_dict_unique)
    a2s_final = dict(adata_annot.obs[['cell_id', 'final_label']].values)

    print("* Updating sdata_final...")
    sdata_final.tables['table_nuclei'].obs['final_label'] = sdata_final.tables['table_nuclei'].obs['cell_id'].map(a2s_final).fillna('Less10')

    sdata_final.tables['table_nuclei'].obs['label1'] = sdata_final.tables['table_nuclei'].obs['label1'].astype(str).fillna('Unknown')
    sdata_final.tables['table_nuclei'].obs['label2'] = sdata_final.tables['table_nuclei'].obs['label2'].astype(str).fillna('Unknown')
    sdata_final.tables['table_nuclei'].obs['label3'] = sdata_final.tables['table_nuclei'].obs['label3'].astype(str).fillna('Unknown')

    sdata_final.tables['table_nuclei'].obs['final_label'] = sdata_final.tables['table_nuclei'].obs['final_label'].replace('nan', 'Unknown')
    sdata_final.tables['table_nuclei'].obs['label1'] = sdata_final.tables['table_nuclei'].obs['label1'].replace('nan', 'Unknown')
    sdata_final.tables['table_nuclei'].obs['label2'] = sdata_final.tables['table_nuclei'].obs['label2'].replace('nan', 'Unknown')
    sdata_final.tables['table_nuclei'].obs['label3'] = sdata_final.tables['table_nuclei'].obs['label3'].replace('nan', 'Unknown')

    print("* Adding color for Napari viz for final labels...")
    sdata_final.tables['table_nuclei'].uns["final_label_colors"] = napari_color

    return sdata_final

# %%
slide_ids = ['breast_s0', 'breast_s1', 'breast_s3', 'breast_s6', 'lung_s1', 'lung_s3', 'skin_s1', 'skin_s2', 'skin_s3', 'skin_s4', 'pancreatic_s0', 
             'pancreatic_s1', 'pancreatic_s2', 'heart_s0', 'colon_s1', 'colon_s2', 'kidney_s0', 'kidney_s1', 'liver_s0', 'liver_s1', 'tonsil_s0',
             'tonsil_s1', 'lymph_node_s0', 'ovary_s0', 'ovary_s1', 'brain_s0', 'bone_marrow_s0', 'bone_marrow_s1', 'bone_s0', 'prostate_s0', 'cervix_s0']
len(slide_ids)
# Out:
# 31

# %%
for slide_id in slide_ids:
    sdata_final = apply_final_labels(slide_id)
    print("* Saving...")
    sdata_final.delete_element_from_disk("table_nuclei")
    sdata_final.write_element("table_nuclei")
# Out:
# ===== Processing slide breast_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide breast_s1 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide breast_s3 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide breast_s6 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide lung_s1 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide lung_s3 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide skin_s1 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide skin_s2 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide skin_s3 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide skin_s4 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide pancreatic_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide pancreatic_s1 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide pancreatic_s2 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide heart_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide colon_s1 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide colon_s2 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide kidney_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide kidney_s1 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide liver_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide liver_s1 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide tonsil_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide tonsil_s1 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide lymph_node_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide ovary_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide ovary_s1 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide brain_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide bone_marrow_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide bone_marrow_s1 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide bone_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide prostate_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
#
# ===== Processing slide cervix_s0 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...

# %%
for slide_id in slide_ids:
    sdata_final = apply_final_labels(slide_id)
    print("* Saving...")
    sdata_final.delete_element_from_disk("table_nuclei")
    sdata_final.write_element("table_nuclei")
# Out:
# ===== Processing slide skin_s4 =====
# * Reading adata_annot...
# * Reading sdata_final...
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'cell_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# /Users/felicie-giraud-sauveur/miniforge3/envs/sopa/lib/python3.10/site-packages/spatialdata/_core/spatialdata.py:158: UserWarning: The table is annotating 'nucleus_boundaries', which is not present in the SpatialData object.
#   self.validate_table_in_spatialdata(v)
# * Applying final labels...
# * Updating sdata_final...
# * Adding color for Napari viz for final labels...
# * Saving...
